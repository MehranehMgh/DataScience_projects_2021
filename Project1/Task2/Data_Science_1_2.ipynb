# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls "/gdrive/My Drive/Crime Data"
# Out:
# Crime_Data_2014.csv  Crime_Data_2016.csv  Crime_Data_2018.csv
# Crime_Data_2015.csv  Crime_Data_2017.csv

# %%
data1 = pd.read_csv('/gdrive/My Drive/Crime Data/Crime_Data_2014.csv')
data2 = pd.read_csv('/gdrive/My Drive/Crime Data/Crime_Data_2015.csv')
data3 = pd.read_csv('/gdrive/My Drive/Crime Data/Crime_Data_2016.csv')
data4 = pd.read_csv('/gdrive/My Drive/Crime Data/Crime_Data_2017.csv')
data5 = pd.read_csv('/gdrive/My Drive/Crime Data/Crime_Data_2018.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # **CRIME TYPE EACH YEAR**

# %% [markdown]
# ##2014

# %%
data1
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED  ... ZIP_CODE       ID
# 0        80-14-048074  2014-06-30 10:46:00  ...    40208    52593
# 1        80-14-004033  2014-01-16 18:20:00  ...    40213   174296
# 2        80-14-057665  2014-08-03 07:48:17  ...    40216   321689
# 3        80-14-092782  2014-12-02 22:50:27  ...    40202   400889
# 4        80-14-092782  2014-12-02 22:50:27  ...    40202   401339
# ...               ...                  ...  ...      ...      ...
# 77461    80-14-098716  2014-12-23 05:03:00  ...    40203  1290945
# 77462    80-14-006480  2014-01-26 21:12:18  ...    40211  1290952
# 77463    80-14-007375  2014-01-29 21:04:00  ...    40219  1142144
# 77464    80-14-025499  2014-04-12 11:38:00  ...    40212  1279223
# 77465    80-14-087204  2014-11-11 21:18:03  ...    40219  1314649
#
# [77466 rows x 15 columns]

# %%
plt.figure(figsize=(50,25))
ax1 = sns.countplot(x = 'CRIME_TYPE', data=data1)
ax1.set_title("CRIME DETAILS IN 2014", fontsize=30)
# Out:
# Text(0.5, 1.0, 'CRIME DETAILS IN 2014')

# %% [markdown]
# ## 2015

# %%
plt.figure(figsize=(50,25))
ax2 = sns.countplot(x = 'CRIME_TYPE', data=data2)
ax2.set_title("CRIME DETAILS IN 2015", fontsize=30)
# Out:
# Text(0.5, 1.0, 'CRIME DETAILS IN 2015')

# %% [markdown]
# ## 2016

# %%
plt.figure(figsize=(50,25))
ax3 = sns.countplot(x = 'CRIME_TYPE', data=data3)
ax3.set_title("CRIME DETAILS IN 2016", fontsize=30)
# Out:
# Text(0.5, 1.0, 'CRIME DETAILS IN 2016')

# %% [markdown]
# ## 2017

# %%
plt.figure(figsize=(50,25))
ax4 = sns.countplot(x = 'CRIME_TYPE', data=data4)
ax4.set_title("CRIME DETAILS IN 2017", fontsize=30)
# Out:
# Text(0.5, 1.0, 'CRIME DETAILS IN 2017')

# %% [markdown]
# ## 2018

# %%
plt.figure(figsize=(50,25))
ax5 = sns.countplot(x = 'CRIME_TYPE', data=data5)
ax5.set_title("CRIME DETAILS IN 2018", fontsize=30)
# Out:
# Text(0.5, 1.0, 'CRIME DETAILS IN 2018')

# %% [markdown]
# #**ALL FIVE YEARS**

# %%
five_years = pd.concat([data1, data2, data3, data4, data5])

# %%
five_years.CRIME_TYPE.describe()
# Out:
# count            403706
# unique               16
# top       THEFT/LARCENY
# freq              78587
# Name: CRIME_TYPE, dtype: object

# %% [markdown]
# #**ZIP CODE FIVE YEARS**

# %%
five_years.ZIP_CODE.describe()
# Out:
# count     401197.0
# unique       137.0
# top        40203.0
# freq       18508.0
# Name: ZIP_CODE, dtype: float64

# %%
mask = five_years.CRIME_TYPE == "THEFT/LARCENY"
five_years[mask].ZIP_CODE.value_counts()
# Out:
# 40219.0    4826
# 40214.0    3994
# 40272.0    2885
# 40216.0    2774
# 40211.0    2529
#            ...
# `             1
# 46845.0       1
# 40025         1
# 40025.0       1
# 40046.0       1
# Name: ZIP_CODE, Length: 80, dtype: int64

# %%
mask = five_years.ZIP_CODE == 40203.0
five_years[mask].CRIME_TYPE.value_counts()
# Out:
# DRUGS/ALCOHOL VIOLATIONS    4609
# ASSAULT                     3731
# THEFT/LARCENY               2321
# VANDALISM                   1585
# OTHER                       1550
# BURGLARY                    1203
# VEHICLE BREAK-IN/THEFT       835
# MOTOR VEHICLE THEFT          737
# FRAUD                        635
# WEAPONS                      561
# ROBBERY                      486
# SEX CRIMES                   112
# DISTURBING THE PEACE         108
# HOMICIDE                      30
# ARSON                          5
# Name: CRIME_TYPE, dtype: int64

# %%
five_years[["CRIME_TYPE",'ZIP_CODE']].groupby("CRIME_TYPE").describe()
# Out:
#                          ZIP_CODE
#                             count unique      top    freq
# CRIME_TYPE
# ARSON                        36.0   23.0  40219.0     5.0
# ASSAULT                   66989.0   77.0  40203.0  3731.0
# BURGLARY                  29556.0   71.0  40214.0  1681.0
# DISTURBING THE PEACE       2316.0   69.0  40203.0   108.0
# DRUGS/ALCOHOL VIOLATIONS  71017.0   74.0  40203.0  4609.0
# DUI                          34.0   22.0  40202.0     4.0
# FRAUD                     21203.0   72.0  40219.0  1096.0
# HOMICIDE                    475.0   55.0  40211.0    46.0
# MOTOR VEHICLE THEFT       18060.0   74.0  40214.0  1017.0
# OTHER                     39655.0  126.0  40218.0  1654.0
# ROBBERY                    7198.0   67.0  40203.0   486.0
# SEX CRIMES                 2644.0   73.0  40219.0   121.0
# THEFT/LARCENY             78472.0   80.0  40219.0  4826.0
# VANDALISM                 28547.0   74.0  40211.0  1604.0
# ...

# %% [markdown]
# # **TREND of INCREASING or DECREASING**

# %% [markdown]
# ## **by months - 2015**

# %%
data2
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED  ... ZIP_CODE       ID
# 0        80-15-095254  2015-11-23 08:30:00  ...    40291    26544
# 1        80-15-075641  2015-09-21 16:00:00  ...    40258    64673
# 2        80-15-048869  2015-06-25 18:19:00  ...    40214    64739
# 3        80-15-073460  2015-09-14 15:27:00  ...    40218    65201
# 4        80-15-080965  2015-10-08 10:03:00  ...    40213    65239
# ...               ...                  ...  ...      ...      ...
# 79834    80-15-102456  2015-12-16 19:18:00  ...    40210  1142238
# 79835    80-15-102464  2015-12-16 20:35:00  ...    40219  1142239
# 79836    80-15-102476  2015-12-16 20:56:00  ...    40208  1142240
# 79837    80-15-102489  2015-12-16 21:29:00  ...    40211  1142241
# 79838    80-15-102484  2015-12-16 21:15:00  ...    40216  1142242
#
# [79839 rows x 15 columns]

# %%
data2.DATE_REPORTED
# Out:
# 0        2015-11-23 08:30:00
# 1        2015-09-21 16:00:00
# 2        2015-06-25 18:19:00
# 3        2015-09-14 15:27:00
# 4        2015-10-08 10:03:00
#                 ...
# 79834    2015-12-16 19:18:00
# 79835    2015-12-16 20:35:00
# 79836    2015-12-16 20:56:00
# 79837    2015-12-16 21:29:00
# 79838    2015-12-16 21:15:00
# Name: DATE_REPORTED, Length: 79839, dtype: object

# %%
data2.DATE_REPORTED.isnull().sum()
# Out:
# 0

# %%
data2.loc[0 , 'DATE_REPORTED']
# Out:
# '2015-11-23 08:30:00'

# %%
data2.loc[0 , 'DATE_REPORTED'].split(" ")[0]
# Out:
# '2015-11-23'

# %%
for i in range (len(data2)):
  temp = data2.loc[i , 'DATE_REPORTED'].split(" ")[0]
  data2.loc[i, 'date'] = temp

# %%
data2.date
# Out:
# 0        2015-11-23
# 1        2015-09-21
# 2        2015-06-25
# 3        2015-09-14
# 4        2015-10-08
#             ...
# 79834    2015-12-16
# 79835    2015-12-16
# 79836    2015-12-16
# 79837    2015-12-16
# 79838    2015-12-16
# Name: date, Length: 79839, dtype: object

# %%
data2['month']=(data2.date.map(lambda x:x.split('-')[1]))

# %%
data2.month
# Out:
# 0        11
# 1        09
# 2        06
# 3        09
# 4        10
#          ..
# 79834    12
# 79835    12
# 79836    12
# 79837    12
# 79838    12
# Name: month, Length: 79839, dtype: object

# %%
#type(data1.month[0])
# Out:
# str

# %%
# data1.month.replace({"01": "Jan", "02": "Feb", "03":"Mar", "04":"Apr", "05":"May", "06":"June", 
#                      "07":"July", "08":"Aug", "09":"Sept", "10":"Oct", "11":"Nov", "12":"Dec"}, inplace = True)

# %%
data2.CRIME_TYPE.unique()
# Out:
# array(['THEFT/LARCENY', 'VANDALISM', 'DRUGS/ALCOHOL VIOLATIONS',
#        'SEX CRIMES', 'ASSAULT', 'WEAPONS', 'DISTURBING THE PEACE',
#        'OTHER', 'VEHICLE BREAK-IN/THEFT', 'MOTOR VEHICLE THEFT',
#        'BURGLARY', 'FRAUD', 'ROBBERY', 'HOMICIDE', 'ARSON', 'DUI'],
#       dtype=object)

# %%
mask = data2.CRIME_TYPE == 'SEX CRIMES'
df = data2[mask].groupby(['month']).count()

mask2 = data2.CRIME_TYPE == 'ASSAULT'
df2 = data2[mask2].groupby(['month']).count()

mask3 = data2.CRIME_TYPE == 'THEFT/LARCENY'
df3 = data2[mask3].groupby(['month']).count()

mask4 = data2.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df4 = data2[mask4].groupby(['month']).count()

mask5 = data2.CRIME_TYPE == 'FRAUD'
df5 = data2[mask5].groupby(['month']).count()

# %%
plt.figure(figsize=(15,10))
plt.title("2015 CRIME TYPES TREND")
sns.lineplot(data=df, x="month", y="CRIME_TYPE", label = "SEX CRIMES")
sns.lineplot(data=df2, x="month", y="CRIME_TYPE", label = 'ASSAULT')
sns.lineplot(data=df3, x="month", y="CRIME_TYPE", label = 'THEFT/LARCENY')
sns.lineplot(data=df4, x="month", y="CRIME_TYPE", label = 'DRUGS/ALCOHOL VIOLATIONS')
sns.lineplot(data=df5, x="month", y="CRIME_TYPE", label = 'FRAUD')

# %% [markdown]
# ## **by months - 2018**

# %%
data5
# Out:
#       INCIDENT_NUMBER    DATE_REPORTED  ... ZIP_CODE       ID
# 0        80-18-037885  5/19/2018 22:16  ...  40215.0   455888
# 1        80-18-037894  5/19/2018 22:54  ...  40211.0   455889
# 2        80-18-032150  4/30/2018 20:37  ...  40203.0   455890
# 3        80-18-037844  5/19/2018 19:19  ...  40218.0   455891
# 4        80-18-037844  5/19/2018 19:19  ...  40218.0   455892
# ...               ...              ...  ...      ...      ...
# 79989    80-18-057236  7/26/2018 20:08  ...  40242.0  1211593
# 79990    80-18-058439   7/31/2018 6:00  ...  40218.0  1211594
# 79991    80-18-059151   8/2/2018 13:30  ...  40212.0  1211595
# 79992    80-18-059395   8/3/2018 20:44  ...  40212.0  1211596
# 79993    80-18-059395   8/3/2018 20:44  ...  40212.0  1211597
#
# [79994 rows x 15 columns]

# %%
data5.DATE_REPORTED
# Out:
# 0        5/19/2018 22:16
# 1        5/19/2018 22:54
# 2        4/30/2018 20:37
# 3        5/19/2018 19:19
# 4        5/19/2018 19:19
#               ...
# 79989    7/26/2018 20:08
# 79990     7/31/2018 6:00
# 79991     8/2/2018 13:30
# 79992     8/3/2018 20:44
# 79993     8/3/2018 20:44
# Name: DATE_REPORTED, Length: 79994, dtype: object

# %%
for i in range (len(data5)):
  temp = data5.loc[i , 'DATE_REPORTED'].split(" ")[0]
  data5.loc[i, 'date'] = temp

# %%
data5.date
# Out:
# 0        5/19/2018
# 1        5/19/2018
# 2        4/30/2018
# 3        5/19/2018
# 4        5/19/2018
#            ...
# 79989    7/26/2018
# 79990    7/31/2018
# 79991     8/2/2018
# 79992     8/3/2018
# 79993     8/3/2018
# Name: date, Length: 79994, dtype: object

# %%
data5['month']=(data5.date.map(lambda x:x.split('/')[0]))

# %%
data5.month
# Out:
# 0        5
# 1        5
# 2        4
# 3        5
# 4        5
#         ..
# 79989    7
# 79990    7
# 79991    8
# 79992    8
# 79993    8
# Name: month, Length: 79994, dtype: object

# %%
data5.CRIME_TYPE.unique()
# Out:
# array(['BURGLARY', 'VANDALISM', 'THEFT/LARCENY', 'FRAUD',
#        'VEHICLE BREAK-IN/THEFT', 'ASSAULT', 'DRUGS/ALCOHOL VIOLATIONS',
#        'OTHER', 'ROBBERY', 'WEAPONS', 'SEX CRIMES', 'MOTOR VEHICLE THEFT',
#        'HOMICIDE', 'DISTURBING THE PEACE', 'ARSON', 'DUI'], dtype=object)

# %%
mask = data5.CRIME_TYPE == 'SEX CRIMES'
df = data5[mask].groupby(['month']).count()

mask2 = data5.CRIME_TYPE == 'VEHICLE BREAK-IN/THEFT'
df2 = data5[mask2].groupby(['month']).count()

mask3 = data5.CRIME_TYPE == 'DISTURBING THE PEACE'
df3 = data5[mask3].groupby(['month']).count()

mask4 = data5.CRIME_TYPE == 'VANDALISM'
df4 = data5[mask4].groupby(['month']).count()

mask5 = data5.CRIME_TYPE == 'THEFT/LARCENY'
df5 = data5[mask5].groupby(['month']).count()

# %%
plt.figure(figsize=(15,10))
plt.title("2018 CRIME TYPES TREND")
sns.lineplot(data=df, x="month", y="CRIME_TYPE", label = "SEX CRIMES")
sns.lineplot(data=df2, x="month", y="CRIME_TYPE", label = 'VEHICLE BREAK-IN/THEFT')
sns.lineplot(data=df3, x="month", y="CRIME_TYPE", label = 'DISTURBING THE PEACE')
sns.lineplot(data=df4, x="month", y="CRIME_TYPE", label = 'VANDALISM')
sns.lineplot(data=df5, x="month", y="CRIME_TYPE", label = 'THEFT/LARCENY')

# %% [markdown]
# ## **BY YEARS**

# %% [markdown]
# ### **THEFT/LARCENY**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'THEFT/LARCENY'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'THEFT/LARCENY'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'THEFT/LARCENY'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'THEFT/LARCENY'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'THEFT/LARCENY'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

# %%
arr
# Out:
# [16427, 15738, 15695, 15064, 15663]

# %%
x = np.array([2014 ,2015,2016,2017, 2018])

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="THEFT/LARCENY")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### **SEX CRIMES**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'SEX CRIMES'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'SEX CRIMES'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'SEX CRIMES'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'SEX CRIMES'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'SEX CRIMES'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

arr
# Out:
# [610, 585, 516, 510, 555]

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="SEX CRIMES", color="seagreen")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### **DRUGS/ALCOHOL VIOLATIONS**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'DRUGS/ALCOHOL VIOLATIONS'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

arr
# Out:
# [14534, 14281, 13805, 14482, 14641]

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="DRUGS/ALCOHOL VIOLATIONS", color="darkred")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### **FRAUD**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'FRAUD'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'FRAUD'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'FRAUD'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'FRAUD'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'FRAUD'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

arr
# Out:
# [3698, 4433, 4349, 4590, 4379]

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="FRAUD", color="salmon")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### **ASSAULT**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'ASSAULT'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'ASSAULT'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'ASSAULT'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'ASSAULT'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'ASSAULT'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

arr
# Out:
# [12316, 13388, 14198, 14029, 13272]

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="ASSAULT", color="teal")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### **ROBBERY**

# %%
arr = []

mask1 = data1.CRIME_TYPE == 'ROBBERY'
df1 = data1[mask1].count()
arr.append(df1.CRIME_TYPE)

mask2 = data2.CRIME_TYPE == 'ROBBERY'
df2 = data2[mask2].count()
arr.append(df2.CRIME_TYPE)

mask3 = data3.CRIME_TYPE == 'ROBBERY'
df3 = data3[mask3].count()
arr.append(df3.CRIME_TYPE)

mask4 = data4.CRIME_TYPE == 'ROBBERY'
df4 = data4[mask4].count()
arr.append(df4.CRIME_TYPE)

mask5 = data5.CRIME_TYPE == 'ROBBERY'
df5 = data5[mask5].count()
arr.append(df5.CRIME_TYPE)

arr
# Out:
# [1569, 1575, 1579, 1364, 1117]

# %%
plt.figure(figsize=(10,5))
my_xticks = ['2014','2015','2016','2017', '2018']
plt.xticks(x, my_xticks)
plt.xlabel("YEARS")
plt.ylabel("NUMBER OF CRIME")
plt.plot(x, arr, label="ROBBERY", color="orchid")
leg = plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# #**WITCH TAKES LONGEST TO REPORT**

# %%
data2
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED  ... ZIP_CODE       ID
# 0        80-15-095254  2015-11-23 08:30:00  ...    40291    26544
# 1        80-15-075641  2015-09-21 16:00:00  ...    40258    64673
# 2        80-15-048869  2015-06-25 18:19:00  ...    40214    64739
# 3        80-15-073460  2015-09-14 15:27:00  ...    40218    65201
# 4        80-15-080965  2015-10-08 10:03:00  ...    40213    65239
# ...               ...                  ...  ...      ...      ...
# 79834    80-15-102456  2015-12-16 19:18:00  ...    40210  1142238
# 79835    80-15-102464  2015-12-16 20:35:00  ...    40219  1142239
# 79836    80-15-102476  2015-12-16 20:56:00  ...    40208  1142240
# 79837    80-15-102489  2015-12-16 21:29:00  ...    40211  1142241
# 79838    80-15-102484  2015-12-16 21:15:00  ...    40216  1142242
#
# [79839 rows x 15 columns]

# %%
data2.DATE_OCCURED.isnull().sum()
# Out:
# 3

# %%
data2[data2['DATE_OCCURED'].isnull()].index.tolist()
# Out:
# [27447, 50146, 52435]

# %%
print(data2.loc[27447 , 'DATE_REPORTED'])
print(data2.loc[50146 , 'DATE_REPORTED'])
print(data2.loc[52435 , 'DATE_REPORTED'])
# Out:
# 2015-06-01 14:24:00
# 2015-07-27 09:55:00
# 2015-09-04 15:40:00

# %%
data2.loc[27447 , 'DATE_OCCURED'] = '2015-06-01 14:24:00'
data2.loc[50146 , 'DATE_OCCURED'] = '2015-07-27 09:55:00'
data2.loc[52435 , 'DATE_OCCURED'] = '2015-09-04 15:40:00'

# %%
data2.DATE_OCCURED.isnull().sum()
# Out:
# 0

# %%
data2.loc[0 , 'DATE_OCCURED']
# Out:
# '2015-11-22 23:00:00'

# %%
type(data2.loc[0 , 'DATE_OCCURED'])
# Out:
# str

# %%
data2.DATE_REPORTED
# Out:
# 0        2015-11-23 08:30:00
# 1        2015-09-21 16:00:00
# 2        2015-06-25 18:19:00
# 3        2015-09-14 15:27:00
# 4        2015-10-08 10:03:00
#                 ...
# 79834    2015-12-16 19:18:00
# 79835    2015-12-16 20:35:00
# 79836    2015-12-16 20:56:00
# 79837    2015-12-16 21:29:00
# 79838    2015-12-16 21:15:00
# Name: DATE_REPORTED, Length: 79839, dtype: object

# %%
type(data2.loc[0 , 'DATE_REPORTED'])
# Out:
# str

# %%
data2.loc[0 , 'DATE_REPORTED'] =  pd.to_datetime(data2.loc[0 , 'DATE_REPORTED'])
data2.loc[0 , 'DATE_REPORTED']
# Out:
# Timestamp('2015-11-23 08:30:00')

# %%
data2.loc[0 , 'DATE_OCCURED'] = pd.to_datetime(data2.loc[0 , 'DATE_OCCURED'])
data2.loc[0 , 'DATE_OCCURED']
# Out:
# Timestamp('2015-11-22 23:00:00')

# %%
data2.loc[0 , 'DATE_REPORTED'] - data2.loc[0 , 'DATE_OCCURED']
# Out:
# Timedelta('0 days 09:30:00')

# %%
str(data2.loc[0 , 'DATE_REPORTED'] - data2.loc[0 , 'DATE_OCCURED'])
# Out:
# '0 days 09:30:00'

# %%
data2['DATE_OCCURED'] = pd.to_datetime(data2['DATE_OCCURED'])
data2['DATE_REPORTED'] = pd.to_datetime(data2['DATE_REPORTED'])

# %%
for i in range (len(data2)):
   day = []
   first = str(data2.loc[i,'DATE_REPORTED'] - data2.loc[i,'DATE_OCCURED'])
   day = first.split(" ")
   data2.loc[i, 'report_long'] = int(day[0])

# %%
data2['report_long']
# Out:
# 0         0.0
# 1         0.0
# 2         0.0
# 3        19.0
# 4         0.0
#          ...
# 79834     0.0
# 79835     0.0
# 79836     1.0
# 79837     0.0
# 79838     0.0
# Name: report_long, Length: 79839, dtype: float64

# %%
plt.figure(figsize=(50,25))
sns.barplot(x='CRIME_TYPE', y='report_long' , data = data2)

# %%
data2[["CRIME_TYPE",'report_long']].groupby("CRIME_TYPE").describe()
# Out:
#                          report_long              ...
#                                count        mean  ...    75%      max
# CRIME_TYPE                                        ...
# ARSON                            4.0    0.000000  ...    0.0      0.0
# ASSAULT                      13388.0    2.773006  ...    0.0   3189.0
# BURGLARY                      6418.0    4.483796  ...    1.0   2381.0
# DISTURBING THE PEACE           548.0    2.899635  ...    0.0    948.0
# DRUGS/ALCOHOL VIOLATIONS     14281.0    0.191163  ...    0.0    622.0
# DUI                              3.0    0.000000  ...    0.0      0.0
# FRAUD                         4433.0  127.358899  ...   29.0   7552.0
# HOMICIDE                        88.0    0.056818  ...    0.0      5.0
# MOTOR VEHICLE THEFT           3234.0    8.143476  ...    1.0   2632.0
# OTHER                         8145.0   20.171025  ...    1.0  12743.0
# ROBBERY                       1575.0    0.350476  ...    0.0    204.0
# ...

# %% [markdown]
# # **CITY ASSOCIATED TO THE INCIDENT**

# %%
data1.CITY.unique()
# Out:
# array(['LOUISVILLE', 'WATTERSON_PARK', 'LYNDON', 'NORWOOD',
#        'HILLS_AND_DALES', nan, 'WEST_BUECHEL', 'MIDDLETOWN',
#        'FOREST_HILLS', 'ST_MATTHEWS', 'DRUID_HILLS', 'RIVERWOOD',
#        'COLDSTREAM', 'PLANTATION', 'HURSTBOURNE_ACRES', 'SHIVELY',
#        'MURRAY_HILL', 'BEECHWOOD_VILLAGE', 'UNK', 'BELLEMEADE',
#        'HOLLYVILLA', 'GREEN_SPRING', 'HURSTBOURNE', 'MEDE',
#        'JEFFERSONTOWN', 'WTWD', 'POPLAR_HILLS', 'LYNNVIEW',
#        'BARBOURMEADE', 'SPRING_VALLEY', 'BLUE_RIDGE_MANOR',
#        'WORTHINGTON_HILLS', 'WOODLAND_HILLS', 'FINCASTLE', 'WINDY_HILLS',
#        'MEDV', 'RICHLAWN', 'LINCOLNSHIRE', 'NORTHFIELD', 'GLENVIEW',
#        'WOODLAWN_PARK', 'GRAYMOOR/DEVONDALE', 'CRESTWOOD', 'MANOR_CREEK',
#        'ROLLING_HILLS', 'WELLINGTON', 'BANCROFT', 'MOORLAND', 'WILDWOOD',
#        'BELLEWOOD', 'ST_REGIS_PARK', 'LANGDON_PLACE', 'SYCAMORE',
#        'GOOSE_CREEK', 'PROSPECT', 'HOLLOW_CREEK', 'BROWNSBORO_VILLAGE',
# ...

# %%
data1.CITY.describe()
# Out:
# count          77385
# unique           109
# top       LOUISVILLE
# freq           73704
# Name: CITY, dtype: object

# %%
data1.CITY.value_counts()
# Out:
# LOUISVILLE           73704
# LVIL                   918
# LYNDON                 469
# MIDDLETOWN             393
# SHIVELY                202
#                      ...
# GMOR                     1
# MISHAWAKA                1
# NORBOURNE_ESTATES        1
# THORNHILL                1
# NEW ALBANY               1
# Name: CITY, Length: 109, dtype: int64

# %%
mask = data1.CITY == "LOUISVILLE"
df1 = data1[mask]

# %%
plt.figure(figsize=(50,25))
sns.countplot(x="CRIME_TYPE", data=df1)

# %%
mask2 = data1.CITY == "LVIL"
df2 = data1[mask2]

# %%
plt.figure(figsize=(50,25))
sns.countplot(x="CRIME_TYPE", data=df2)

# %% [markdown]
# # **PREMISE_TYPE**

# %%
data1.PREMISE_TYPE.unique()
# Out:
# array(['HIGHWAY / ROAD / ALLEY', 'OTHER / UNKNOWN',
#        'PARKING LOT / GARAGE', 'CONVENIENCE STORE', 'RESIDENCE / HOME',
#        'HOTEL / MOTEL / ETC.', 'DEPARTMENT / DISCOUNT STORE',
#        'OTHER RESIDENCE (APARTMENT/CONDO)', 'GROCERY / SUPERMARKET',
#        'SPECIALTY STORE (TV, FUR, ETC)', 'ATM SEPARATE FROM BANK',
#        'RESTAURANT', 'INDUSTRIAL SITE', 'LIQUOR STORE',
#        'COMMERCIAL / OFFICE BUILDING', 'DRUG STORE/DR`S OFFICE/HOSPITAL',
#        'BANK / SAVINGS & LOAN', 'SCHOOL - ELEMENTARY / SECONDARY',
#        'PARK / PLAYGROUND', 'MALL / SHOPPING CENTER', 'CONSTRUCTION SITE',
#        'SERVICE / GAS STATION', 'NON-ATTACHED RESD GARAGE/SHED/BULD',
#        'GOVERNMENT / PUBLIC BUILDING', 'CHURCH / SYNAGOGUE / TEMPLE', nan,
#        'BAR / NIGHT CLUB', 'FAIRGROUNDS / STADIUM / ARENA',
#        'RENTAL / STORAGE FACILITY', 'SCHOOL - COLLEGE / UNIVERSITY',
#        'CHILD DAYCARE FACILITY', 'JAIL / PENITENTARY',
# ...

# %%
data1.PREMISE_TYPE.describe()
# Out:
# count                77395
# unique                  44
# top       RESIDENCE / HOME
# freq                 27213
# Name: PREMISE_TYPE, dtype: object

# %%
data1.PREMISE_TYPE.value_counts()
# Out:
# RESIDENCE / HOME                      27213
# HIGHWAY / ROAD / ALLEY                16203
# PARKING LOT / GARAGE                   5882
# OTHER RESIDENCE (APARTMENT/CONDO)      5513
# DEPARTMENT / DISCOUNT STORE            4683
# OTHER / UNKNOWN                        4206
# GROCERY / SUPERMARKET                  1642
# RESTAURANT                             1087
# SERVICE / GAS STATION                  1048
# CONVENIENCE STORE                      1027
# DRUG STORE/DR`S OFFICE/HOSPITAL         926
# SPECIALTY STORE (TV, FUR, ETC)          881
# COMMERCIAL / OFFICE BUILDING            869
# HOTEL / MOTEL / ETC.                    779
# SCHOOL - ELEMENTARY / SECONDARY         701
# NON-ATTACHED RESD GARAGE/SHED/BULD      592
# BAR / NIGHT CLUB                        590
# PARK / PLAYGROUND                       572
# BANK / SAVINGS & LOAN                   472
# GOVERNMENT / PUBLIC BUILDING            317
# CHURCH / SYNAGOGUE / TEMPLE             288
# ...

# %%
mask = data1.PREMISE_TYPE == "RESIDENCE / HOME"
df1 = data1[mask]

# %%
plt.figure(figsize=(50,25))
sns.countplot(x="CRIME_TYPE", data=df1)

# %%
mask2 = data1.PREMISE_TYPE == "HIGHWAY / ROAD / ALLEY"
df2 = data1[mask2]

# %%
plt.figure(figsize=(50,25))
sns.countplot(x="CRIME_TYPE", data=df2)
